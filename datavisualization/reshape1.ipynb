# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (6,5)
plt.rcParams['figure.dpi'] = 150

# %%
x = np.random.randn(5000,2)

# %%
x[:5]
# Out:
# array([[ 0.51682222, -1.78757168],
#        [ 0.1011482 , -0.95990171],
#        [-0.07713137, -1.44767114],
#        [-0.28550979, -0.57365248],
#        [ 0.05151529, -0.76688086]])

# %%
x2 = np.random.randint(140, 340, size=(5000,2))

# %%
x2[:5]
# Out:
# array([[218, 271],
#        [261, 152],
#        [313, 250],
#        [284, 207],
#        [338, 195]])

# %%
features = x[:, 0]
target = x[:, -1]

features2 = x2[:, 0]
target2 = x2[:, -1]

# %%
plt.scatter(target, features, color='r')

# %%
plt.scatter(target2, features2, color='g')

# %%
target.shape
# Out:
# (5000,)

# %%
print(type(target))
print(type(features))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
target[:5]
# Out:
# array([-1.78757168, -0.95990171, -1.44767114, -0.57365248, -0.76688086])

# %%
t = target.reshape(5000 ,1)

# %%
print(type(t))
print(t[:5])
t[-5:]
# Out:
# <class 'numpy.ndarray'>
# [[-1.78757168]
#  [-0.95990171]
#  [-1.44767114]
#  [-0.57365248]
#  [-0.76688086]]
# array([[-0.93155441],
#        [ 0.62900284],
#        [ 0.00601983],
#        [-0.25468723],
#        [-0.52959435]])

# %%
t.shape
# Out:
# (5000, 1)

# %%
u = target.reshape(-1, 1)

# %%
print(u.shape)
print(u[:5])
# Out:
# (5000, 1)
# [[-1.78757168]
#  [-0.95990171]
#  [-1.44767114]
#  [-0.57365248]
#  [-0.76688086]]

# %%
uu = target.reshape(2, -1, 5)

# %%
uu.shape
# Out:
# (2, 500, 5)
